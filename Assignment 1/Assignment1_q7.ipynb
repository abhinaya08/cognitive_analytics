# %%
from fastai.vision import *

# %% [markdown]
# ## Dowloading images for coloseum rome, eifel tower and UT tower

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Mounted at /content/gdrive

# %%
path = Path(base_dir + 'data/landmarks')

# %%
folder = 'coloseum'
file = 'urls_colosseum_rome.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:42<00:00]
#     </div>
# ...

# %%
folder = 'eiffel'
file = 'urls_eiffel_tower_paris.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='309' class='' max='309', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [309/309 00:31<00:00]
#     </div>

# %%
folder = 'uttower'
file = 'urls_ut_tower.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:35<00:00]
#     </div>
# Error https://img.washingtonpost.com/wp-apps/imrs.php?src=https://img.washingtonpost.com/news/local/wp-content/uploads/sites/2/2016/07/BabyBoyWilsonGrave.jpg&w=1484 HTTPSConnectionPool(host='img.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# ...

# %%
classes = ['coloseum','eiffel','uttower']

# %%
#removing all bad images
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# coloseum
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='399' class='' max='399', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [399/399 00:16<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='/content/gdrive/My Drive/fastai-v3/data/landmarks/coloseum/00000120.jpg'>
# cannot identify image file <_io.BufferedReader name='/content/gdrive/My Drive/fastai-v3/data/landmarks/coloseum/00000002.jpg'>
# ...

# %% [markdown]
# ## Loading data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['coloseum', 'eiffel', 'uttower']

# %%
data.show_batch(rows=4, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['coloseum', 'eiffel', 'uttower'], 3, 832, 208)

# %% [markdown]
# ## Training model using ResNet34

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:01<00:00, 76548153.14it/s]

# %%
# training 4 epochs usng one_cycle method
learn.fit_one_cycle(4)
# Out:
# Total time: 02:33 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.890516</th>
#     <th>0.316507</th>
#     <th>0.129808</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.520951</th>
#     <th>0.280571</th>
#     <th>0.105769</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.378705</th>
#     <th>0.283460</th>
#     <th>0.100962</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.297220</th>
#     <th>0.289240</th>
#     <th>0.110577</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Fine tuning ResNet34

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (832 items)
# [Category coloseum, Category coloseum, Category coloseum, Category coloseum, Category coloseum]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks
# x: ImageItemList (832 items)
# [Image (3, 333, 499), Image (3, 500, 333), Image (3, 320, 480), Image (3, 280, 390), Image (3, 266, 355)]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks;
#
# Valid: LabelList
# y: CategoryList (208 items)
# [Category coloseum, Category uttower, Category coloseum, Category coloseum, Category uttower]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks
# x: ImageItemList (208 items)
# [Image (3, 384, 500), Image (3, 281, 500), Image (3, 492, 500), Image (3, 267, 400), Image (3, 281, 500)]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %%
#Using learning rate finder to identify the learning rate at which the conv net can train the fastest
learn.unfreeze()
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Loss diverges ater 5 epochs
learn.recorder.plot()

# %%
#unfreezing all layers
learn.unfreeze()

# %%
#passing range of learning rates based on the plot
learn.fit_one_cycle(5, max_lr=slice(1e-6,1e-5))
# Out:
# Total time: 01:44 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.121369</th>
#     <th>0.286790</th>
#     <th>0.110577</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.120470</th>
#     <th>0.288776</th>
#     <th>0.115385</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.130508</th>
#     <th>0.277363</th>
#     <th>0.115385</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.130849</th>
#     <th>0.265972</th>
#     <th>0.100962</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.126913</th>
#     <th>0.276654</th>
#     <th>0.110577</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation of ResNet34

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# Looks like the most confused are images that are arbitary images that do not correspond to any particular landmark.

# %%
interp.most_confused(min_val=2)
# Out:
# [('eiffel', 'uttower', 12),
#  ('coloseum', 'uttower', 4),
#  ('uttower', 'eiffel', 3)]

# %% [markdown]
# ## Data Augmentation

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=True, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch(rows=4, figsize=(7,8))

# %% [markdown]
# ## Trying ResNet50

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:02<00:00, 34919048.74it/s]

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 01:19 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.678610</th>
#     <th>0.511038</th>
#     <th>0.161325</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.462792</th>
#     <th>0.354782</th>
#     <th>0.120726</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.327041</th>
#     <th>0.375049</th>
#     <th>0.108974</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.255719</th>
#     <th>0.372739</th>
#     <th>0.110043</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.215342</th>
#     <th>0.349544</th>
#     <th>0.107906</th>
#   </tr>
# </table>

# %%
learn.save('stage-1-50')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(3,slice(5e-4,1e-3))
# Out:
# Total time: 00:49 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.029597</th>
#     <th>0.592768</th>
#     <th>0.139957</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.015780</th>
#     <th>0.499710</th>
#     <th>0.123932</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.031925</th>
#     <th>0.465729</th>
#     <th>0.118590</th>
#   </tr>
# </table>

# %%
learn.save('stage-2-50')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# ## Cleaning up
#
# #### Explored code, but it doesnt work on GCP
#
# https://forums.fast.ai/t/imagecleaner-doesnt-render/37152/6

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-c4b481dd1224> in <module>()
# ----> 1 learn = create_cnn(data, models.resnet50, metrics=error_rate)
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py in create_cnn(data, arch, cut, pretrained, lin_ftrs, ps, custom_head, split_on, bn_final, **kwargs)
#      63     head = custom_head or create_head(nf, data.c, lin_ftrs, ps=ps, bn_final=bn_final)
#      64     model = nn.Sequential(body, head)
# ---> 65     learn = Learner(data, model, **kwargs)
#      66     learn.split(ifnone(split_on,meta['split']))
#      67     if pretrained: learn.freeze()
#
# <string> in __init__(self, data, model, opt_func, loss_func, metrics, true_wd, bn_wd, wd, train_bn, path, model_dir, callback_fns, callbacks, layer_groups)
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in __post_init__(self)
# ...

# %%
learn.load('stage-2-50')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (104 items)
# [Category coloseum, Category coloseum, Category coloseum, Category coloseum, Category coloseum]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks
# x: ImageItemList (104 items)
# [Image (3, 500, 333), Image (3, 349, 236), Image (3, 500, 321), Image (3, 418, 236), Image (3, 320, 450)]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks;
#
# Valid: LabelList
# y: CategoryList (936 items)
# [Category coloseum, Category uttower, Category coloseum, Category coloseum, Category uttower]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks
# x: ImageItemList (936 items)
# [Image (3, 384, 500), Image (3, 281, 500), Image (3, 492, 500), Image (3, 267, 400), Image (3, 281, 500)]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8a8d23411355> in <module>()
# ----> 1 ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
#
# NameError: name 'DatasetFormatter' is not defined

# %%
#Code to remove duplicate images while training
ImageCleaner(ds, idxs, path, duplicates=True)

# %%
np.random.seed(42)
data = ImageDataBunch.from_csv(".", folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# ## Exporting ResNet 50 model

# %%
#exporting final model
learn.export()

# %% [markdown]
# ## Code in Production

# %%
learn = load_learner(path)

# %%
defaults.device = torch.device('cpu')

# %%
#Testing the performance on lighthouse photos
folder = 'lighthouse'
file = 'lighthouse.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=5)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00]
#     </div>

# %%
src = ImageItemList.from_folder(path/'lighthouse')
src
# Out:
# ImageItemList (89 items)
# [Image (3, 856, 922), Image (3, 500, 750), Image (3, 1042, 1850), Image (3, 640, 960), Image (3, 333, 220)]...
# Path: /content/gdrive/My Drive/fastai-v3/data/landmarks/lighthouse

# %%
img = open_image(path/folder/"00000000.jpg")
img
# Out:
# Image (3, 333, 220)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category uttower

# %% [markdown]
# Model predicts lighthouse at UT-Tower. They look similar, so it makes sense
